# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
hello=tf.constant("Hello, Tensor!")

# %%
model=tf.keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(32,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
data=np.random.random((1000, 32))
labels=np.random.random((1000, 10))
model.fit(data, labels, epochs=10, batch_size=32)
# Out:
# Train on 1000 samples
# Epoch 1/10
# 1000/1000 [==============================] - 0s 492us/sample - loss: 11.8531 - accuracy: 0.1000
# Epoch 2/10
# 1000/1000 [==============================] - 0s 41us/sample - loss: 16.1439 - accuracy: 0.0990
# Epoch 3/10
# 1000/1000 [==============================] - 0s 40us/sample - loss: 25.8643 - accuracy: 0.1050
# Epoch 4/10
# 1000/1000 [==============================] - 0s 39us/sample - loss: 45.5066 - accuracy: 0.1150
# Epoch 5/10
# 1000/1000 [==============================] - 0s 39us/sample - loss: 71.6153 - accuracy: 0.1090
# Epoch 6/10
# 1000/1000 [==============================] - 0s 38us/sample - loss: 101.9334 - accuracy: 0.1020
# Epoch 7/10
# 1000/1000 [==============================] - 0s 39us/sample - loss: 130.5282 - accuracy: 0.1120
# Epoch 8/10
# 1000/1000 [==============================] - 0s 39us/sample - loss: 148.1717 - accuracy: 0.1090
# Epoch 9/10
# 1000/1000 [==============================] - 0s 38us/sample - loss: 152.0664 - accuracy: 0.0930
# Epoch 10/10
# 1000/1000 [==============================] - 0s 39us/sample - loss: 153.9596 - accuracy: 0.1010

# %%
dataset=tf.data.Dataset.from_tensor_slices((data, labels))
dataset=dataset.batch(32)
model.fit(dataset, epochs=10, steps_per_epoch=30)
# Out:
# Train for 30 steps
# Epoch 1/10
# 30/30 [==============================] - 0s 2ms/step - loss: 161.8227 - accuracy: 0.0979
# Epoch 2/10
#  1/30 [>.............................] - ETA: 0s - loss: 179.4354 - accuracy: 0.0938WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 300 batches). You may need to use the repeat() function when building your dataset.

# %%
data=np.random.random((1000, 32))
labels=np.random.random((1000,10))

# %%
model.evaluate(data, labels, batch_size=32)
model.evaluate(dataset, steps=30)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 30/30 [==============================] - 0s 869us/step - loss: 170.1273 - accuracy: 0.1146
# [170.1272959391276, 0.114583336]

# %%
result=model.predict(data, batch_size=32)
print(result.shape)
# Out:
# (1000, 10)

# %%
inputs=keras.Input(shape=(784,), name='digits')
